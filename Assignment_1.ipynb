# %% [markdown]
# <a href="https://colab.research.google.com/github/Mitalinvs/Machine-Learning/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q11. WAP to calculate the time taken by a program

# %%
import time

start= time.time()

print(23*2.3)

end= time.time()
print(end-start)
# Out:
# 52.9
# 0.00020122528076171875

# %% [markdown]
# Q12. WAP to sort following number of elements in a list, calculate time taken and plot the graph

# %%
import time
import matplotlib.pyplot as plt

def time_cal(num):
  start= time.time()
  L= list(range(1, num + 1))
  L.sort()
  end= time.time()
  return end-start

num_elements= [5000, 10000, 20000, 15000, 25000]
times= []

for i in num_elements:
  times.append(time_cal(i))

print(times)

plt.plot(num_elements, times)
plt.xlabel('Number of Elements')
plt.ylabel('Time taken (seconds)')
plt.title('Sorting Time vs Number of Elements')
plt.show()
# Out:
# [0.00020623207092285156, 0.0003936290740966797, 0.0032453536987304688, 0.0005128383636474609, 0.0007379055023193359]
